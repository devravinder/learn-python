# %% [markdown]
# # Exception Handling
#
# Using `try`, `except`, and `finally` to handle runtime errors gracefully.

# %% [markdown]
# ## Basic try-except-finally

# %%
try:
    num = int(input("Enter number: ")) # give string
    print("Square:", num * num)
except ValueError:
    print("Invalid number")
finally:
    print("Go to another")
# Out:
# Invalid number
# Go to another

# %% [markdown]
# ## Catching Exception Details with `as`

# %%
try:
    num = int(input("Enter number: ")) # give string
    print("Square:", num * num)
except ValueError as e:
    print("Invalid number")
    print("Error info:", e)
finally:
    print("Program done")
# Out:
# Invalid number
# Error info: invalid literal for int() with base 10: 'hh'
# Program done
