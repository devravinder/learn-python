# %% [markdown]
# # Operators
#
# Python supports arithmetic, assignment, comparison, logical, identity, and membership operators.

# %% [markdown]
# ## Arithmetic Operators
#
# Note: `//` is integer division, `**` is exponentiation, `%` is modulus.

# %%
a, b = 10, 3

print(a+b)
print(a-b)
print(a*b)
print(a/b)  # 3.3333333333333335
print(a//b)  # for integer = 3  # does floor
print(a % b)  # modulus / remainder
print(a**b) # exponential a power b
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 10//3 =  3
# 5//2 =  2
# 15//4 =  2
# 1
# 1000

# %% [markdown]
# ## Assignment Operators
#
# Self-assigning operators like `+=`, `-=`, `*=`, etc.

# %%
x=3
x+=5 # self assigning
print(x)
# Out:
# 8

# %% [markdown]
# ## Comparison Operators
#
# Operators: `<`, `>`, `<=`, `>=`, `==`, `!=`
#
# Note: Comparing different types (e.g., int and string) and string comparisons use ASCII values.

# %%
print("============comparision============")
# <, >, <=, >=, ==, !=
print(f"a={a}, b={b}")
print(f"a<b:{a<b}, a>b:{a>b}, a<=b:{a<=b}, a>=b:{a>=b}, a==b:{a==b}, a!=b:{a!=b}")

print(10=="10") # False
print(10!="10")

print("---------------------------")
print("bag" > "apple") # True b > a
print("bag"=="BAG") # False
print(f"ord(\"b\")={ord('b')}") # a=97, b=98
# Out:
# ============comparision============
# a=10, b=3
# a<b:False, a>b:True, a<=b:False, a>=b:True, a==b:False, a!=b:True
# False
# True
# ---------------------------
# True
# False
# ord("b")=98

# %% [markdown]
# ## Logical Operators (and, or, not)
#
# Used to combine conditional statements.

# %%
#---- and
age = 20
is_student = True

if age >= 18 and is_student:
    print("You are eligible for student discount")
else:
    print("Not eligible")
# Out:
# You are eligible for student discount

# %%
#---- or
day = "Saturday"

if day == "Saturday" or day == "Sunday":
    print("Weekend")
else:
    print("Weekday")

#----- not
is_logged_in = False

if not is_logged_in:
    print("Please login first")
else:
    print("Welcome!")
# Out:
# Weekend
# Please login first

# %% [markdown]
# ## Identity Operators (is, is not)
#
# `is` checks if two variables refer to the same object in memory.

# %%
# ---- is
x = 2
y = 2

if x is y:
    print(" Same ")

#---- is not
y = 3
if x is not y:
    print(" Not Same ")
# Out:
#  Same
#  Not Same

# %% [markdown]
# ## Short Circuit & Chaining
#
# Python supports short-circuit evaluation and chained comparisons (like math notation).

# %%
#--------------- short circuit with logical operator
age = 20
has_id = True
is_banned = False

if (age >= 18 and has_id) or not is_banned:
    print("Entry allowed")
else:
    print("Entry denied")


x = 5
print("OK" if (x > 0 and x < 10) or not False else "NO") # ternary operator


print("=================chaining comparison operators==========")
# like maths
x = 20

if 18 < x <= 21:
    print("Teenager (18 to 21 range)")
else:
    print("Not in the range")
# Out:
# Entry allowed
# OK
# =================chaining comparison operators==========
# Teenager (18 to 21 range)

# %% [markdown]
# ## Membership Operators (in, not in)
#
# Check if a value exists in a sequence (list, string, tuple, etc.).

# %%
age_list = [2,3,4,5,6,7]
kid = 5
adult = 18

print( kid in age_list )
print( adult not in age_list )
# Out:
# True
# True
