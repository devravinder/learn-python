# %% [markdown]
# # Match Statement (Python 3.10+)
# ## Very Important - Different from Other Programming Langugages
# Python's structural pattern matching - similar to switch/case in other languages.

# %% [markdown]
# ## Basic Match

# %%
day = 3

match day:
    case 1:
        print("Sunday")
    case 2:
        print("Monday")
    case 3:
        print("Tuesday")
    case 4:
        print("Wednesday")
    case _:  # default
        print("Invalid day")
# Out:
# Tuesday

# %% [markdown]
# ## Match with Strings

# %%
fruit = "apple"

match fruit:
    case "apple":
        print("Red fruit")
    case "banana":
        print("Yellow fruit")
    case "orange":
        print("Citrus fruit")
    case _:
        print("Unknown fruit")
# Out:
# Red fruit

# %% [markdown]
# ## Match with OR Pattern (|)

# %%
color = "blue"

match color:
    case "red" | "maroon":
        print("Warm color")
    case "blue" | "skyblue":
        print("Cool color")
    case _:
        print("Unknown color")
# Out:
# Cool color

# %% [markdown]
# ## Pattern Matching with Tuples

# %%
user = ("Ravi", 25)

match user:
    case (name, age):
        print(f"Name: {name}, Age: {age}")
# Out:
# Name: Ravi, Age: 25

# %% [markdown]
# ## Match with Guard (if condition)

# %%
num = 10

match num:
    case n if n > 0:
        print("Positive")
    case n if n < 0:
        print("Negative")
    case 0:
        print("Zero")
# Out:
# Positive
