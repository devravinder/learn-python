# %% [markdown]
# # Ternary Operator
#
# Python's inline conditional expression: `value_if_true if condition else value_if_false`

# %%
# ternary operator with if & else

age = 18
message = "Adult" if age >= 18 else "Minor"
print(message)
