# %% [markdown]
# # File Handling
#
# Reading and writing files in Python using `open()`.

# %% [markdown]
# ## Writing to a File

# %%
# write
file = open("demo.txt", "w")
file.write("Hello Python\n")
file.close()

# %% [markdown]
# ## Reading from a File

# %%
# read
file = open("demo.txt", "r")
print(file.read())
file.close()
# Out:
# Hello Python
